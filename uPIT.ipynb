# %% [markdown]
# <a href="https://colab.research.google.com/github/winner96/uPIT-Speech-Separation/blob/master/uPIT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/winner96/uPIT-Speech-Separation.git
# Out:
# Cloning into 'uPIT-Speech-Separation'...
# remote: Enumerating objects: 92, done.
# remote: Counting objects: 100% (92/92), done.
# remote: Compressing objects: 100% (64/64), done.
# remote: Total 92 (delta 38), reused 59 (delta 23), pack-reused 0
# Unpacking objects: 100% (92/92), done.

# %%
root = "/content/uPIT-Speech-Separation"
# !echo $root
# Out:
# /content/uPIT-Speech-Separation

# %%
# %cd $root
# !ls
# Out:
# compute_cmvn.py  dataset.py.old      pretrain-model    scripts	    train.sh
# conf		 make_scp.py	     README.md	       separate.py  utils.py
# dataset.py	 model.py	     requirements.txt  test.sh
# dataset.py.exit  oracle_separate.py  run_pit.py        trainer.py

# %%
avs_data_z = "avs_audio.zip"
avs_data = "avs_audio"
#![ ! -f $avs_data_z ] && cp /content/drive/MyDrive/$avs_data_z ./$avs_data_z && echo "zip downloaded"
print("start donwload")
![ ! -f $avs_data_z ] && rsync -progress /content/drive/MyDrive/$avs_data_z ./$avs_data_z && echo "zip downloaded"

print("start unzip")
#![ ! -d $root/$avs_data ] && unzip ./$avs_data_z -d $root && echo "zip unziped"
![ ! -d $root/$avs_data ] && jar xvf ./$avs_data_z && echo "zip unziped"
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#  inflated: avs_audio/avs_tr/spk2/uNKDV0d8cR4.wav
#  inflated: avs_audio/avs_tr/spk2/unli-5Lfe-Y.wav
#  inflated: avs_audio/avs_tr/spk2/UNOtehNSJv8.wav
#  inflated: avs_audio/avs_tr/spk2/uNsw6--fvOc.wav
#  inflated: avs_audio/avs_tr/spk2/UO1n4KWjGDo.wav
#  inflated: avs_audio/avs_tr/spk2/uO7HkTrRzwM.wav
#  inflated: avs_audio/avs_tr/spk2/uO82R8wNkgI.wav
#  inflated: avs_audio/avs_tr/spk2/uoC2ZGRI8a8.wav
#  inflated: avs_audio/avs_tr/spk2/UODXwkMOOXM.wav
#  inflated: avs_audio/avs_tr/spk2/UOEb9_rWk0A.wav
#  inflated: avs_audio/avs_tr/spk2/uoEDu6FD-5A.wav
#  inflated: avs_audio/avs_tr/spk2/uoKf-RLDKHI.wav
#  inflated: avs_audio/avs_tr/spk2/uOlElkQiLvg.wav
#  inflated: avs_audio/avs_tr/spk2/UoMzI6ycd4Q.wav
#  inflated: avs_audio/avs_tr/spk2/-UozLT647NY.wav
#  inflated: avs_audio/avs_tr/spk2/uP_IqBvX540.wav
#  inflated: avs_audio/avs_tr/spk2/uP5nogcfzGQ.wav
#  inflated: avs_audio/avs_tr/spk2/uPa8XKYRlUA.wav
# ...

# %%
pip install -r /content/uPIT-Speech-Separation/requirements.txt
# Out:
# ...
#      |████████████████████████████████| 773.1MB 22kB/s
# ...
#      |████████████████████████████████| 51kB 7.0MB/s
# ...
#      |████████████████████████████████| 1.6MB 55.8MB/s
# ...
#      |████████████████████████████████| 25.2MB 135kB/s
# ...
#      |████████████████████████████████| 17.3MB 118kB/s
# ...
#      |████████████████████████████████| 276kB 55.2MB/s
# ...
#   Created wheel for librosa: filename=librosa-0.7.1-cp36-none-any.whl size=1610157 sha256=b3dab8006da86b942da7dabd98e31b332c2f620cd48aa60e08c264a3ac38fd79
#   Stored in directory: /root/.cache/pip/wheels/07/36/47/a9a4d151332cbdaec564500af9704a0ad862cf554dcf4bfda0
# ...
#   Created wheel for PyYAML: filename=PyYAML-5.1.1-cp36-cp36m-linux_x86_64.whl size=44100 sha256=81ce83b6d2694a00ef9c40a4830f0ae3f8fbafad2def2417b7c9519d8689715a
#   Stored in directory: /root/.cache/pip/wheels/16/27/a1/775c62ddea7bfa62324fd1f65847ed31c55dadb6051481ba3f
# Successfully built librosa PyYAML
# ...

# %%
# !chmod -R 755 $root

# !ls -al $root
# Out:
# total 132
# drwxr-xr-x 7 root root  4096 Nov 22 12:34 .
# drwxr-xr-x 1 root root  4096 Nov 22 12:24 ..
# drwxr-xr-x 5 root root  4096 Nov 22 12:38 avs_audio
# -rwxr-xr-x 1 root root  2393 Nov 22 11:39 compute_cmvn.py
# drwxr-xr-x 3 root root  4096 Nov 22 11:39 conf
# -rwxr-xr-x 1 root root  5102 Nov 22 11:39 dataset.py
# -rwxr-xr-x 1 root root  8219 Nov 22 11:39 dataset.py.exit
# -rwxr-xr-x 1 root root 10665 Nov 22 11:39 dataset.py.old
# drwxr-xr-x 8 root root  4096 Nov 22 11:39 .git
# -rwxr-xr-x 1 root root   111 Nov 22 11:39 .gitignore
# -rwxr-xr-x 1 root root  2504 Nov 22 11:39 make_scp.py
# -rwxr-xr-x 1 root root  2299 Nov 22 11:39 model.py
# -rwxr-xr-x 1 root root  3887 Nov 22 11:39 oracle_separate.py
# drwxr-xr-x 2 root root  4096 Nov 22 11:39 pretrain-model
# -rwxr-xr-x 1 root root  1834 Nov 22 11:39 README.md
# -rwxr-xr-x 1 root root    86 Nov 22 11:39 requirements.txt
# -rwxr-xr-x 1 root root  5529 Nov 22 11:39 run_pit.py
# drwxr-xr-x 2 root root  4096 Nov 22 11:39 scripts
# ...

# %%
# !python $root/make_scp.py
# Out:
# /content/uPIT-Speech-Separation/scp already exists
# train scp done
# test scp done
# cross validation scp done

# %%
![ ! -f $root/cmvn.dict ] && python $root/compute_cmvn.py $root/scp/tr_mx.scp $root/cmvn.dict
# Out:
# hey : /content/uPIT-Speech-Separation/scp/tr_mx.scp
# 2020-11-22 13:07:13,242 [/content/uPIT-Speech-Separation/dataset.py:28 - INFO ] Create SpectrogramReader for /content/uPIT-Speech-Separation/scp/tr_mx.scp with 11000 utterances
# ...

# %%
import pickle

# %%
#!python3 /content/uPIT-for-speech-separation/run_pit.py --config /content/drive/MyDrive/configs/2config.yaml --num-epoches 100 > /content/uPIT-for-speech-separation/check/train.log 2>&1 &
# !python $root/run_pit.py --config $root/configs/2config.yaml
# !echo sibal
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 2020-11-22 14:23:33,480 [/content/uPIT-Speech-Separation/dataset.py:48 - INFO ] key : kCGtgQWiLAA_zWr1CtH3RQQ
# 2020-11-22 14:23:33,496 [/content/uPIT-Speech-Separation/dataset.py:48 - INFO ] key : _FLv5ycuKc4_a5zQ8gItbkg
# 2020-11-22 14:23:33,507 [/content/uPIT-Speech-Separation/dataset.py:48 - INFO ] key : _FLv5ycuKc4_a5zQ8gItbkg
# 2020-11-22 14:23:33,522 [/content/uPIT-Speech-Separation/dataset.py:48 - INFO ] key : _FLv5ycuKc4_a5zQ8gItbkg
# 2020-11-22 14:23:33,535 [/content/uPIT-Speech-Separation/dataset.py:48 - INFO ] key : k1DC1quoS50_zKdnrObcSuM
# 2020-11-22 14:23:33,549 [/content/uPIT-Speech-Separation/dataset.py:48 - INFO ] key : k1DC1quoS50_zKdnrObcSuM
# 2020-11-22 14:23:33,559 [/content/uPIT-Speech-Separation/dataset.py:48 - INFO ] key : k1DC1quoS50_zKdnrObcSuM
# 2020-11-22 14:23:33,586 [/content/uPIT-Speech-Separation/dataset.py:48 - INFO ] key : aL9GK9x_fWw_n7ADKb_oQCs
# ...

# %%
# !nvidia-smi

# %%
# !echo why
# Out:
# why
